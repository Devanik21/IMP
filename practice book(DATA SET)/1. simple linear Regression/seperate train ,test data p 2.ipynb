# %%
from pandas import *
from seaborn import *
from matplotlib.pyplot import *
from sklearn.linear_model import LinearRegression

# %%
df=read_csv('Salary_Data.csv')

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   54731
# 3               2.0   63525
# 4               2.2   69891
# 5               2.9   76642
# 6               3.0   80150
# 7               3.2   84445
# 8               3.5   94445
# 9               3.7  107189
# 10              3.9  113218
# 11              4.0  125794
# 12              4.1  127081
# 13              4.5  150111
# 14              4.9  155938
# 15              5.1  166029
# 16              5.3  173088
# 17              5.9  181363
# 18              6.0  193940
# 19              6.8  211738
# 20              7.1  238273
# 21              7.9  251302
# 22              8.2  293812
# 23              8.7  309431
# 24              9.0  355582
# 25              9.5  366969
# 26              9.6  372635
# 27             10.3  422391
# 28             10.5  444872

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        29.000000      29.000000
# mean          5.368966  185177.000000
# std           2.869557  120089.789582
# min           1.100000   39343.000000
# 25%           3.200000   84445.000000
# 50%           4.900000  155938.000000
# 75%           7.900000  251302.000000
# max          10.500000  444872.000000

# %%
x= df.iloc[:, 0:1].values  # or -> x=df.iloc[: , :-1].values 
y = df.iloc[:, 1].values
scatter(x,y)
xlabel('Experience ')
ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
r=LinearRegression()
r.fit(x,y)
# Out:
# LinearRegression()

# %%
r.score(x,y)
# Out:
# 0.9695951027139296

# %%
r.predict([[4.7]])
# Out:
# array([157609.96181147])

# %%
scatter(x,r.predict(x),color='Blue')
plot(x,y)
show()

# %%
from sklearn.preprocessing import PolynomialFeatures
r2=PolynomialFeatures(degree=13)  #overall  - lower degree is versatile 
x2=r2.fit_transform(x)

# %%
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x2, y)
# Out:
# LinearRegression()

# %%
lin_reg_2.score(x2,y)
# Out:
# 0.9980197185163246

# %%
pred= lin_reg_2.predict(r2.fit_transform([[4.7]]))
pred
# Out:
# array([153938.87541866])

# %%
scatter(x,lin_reg_2.predict(x2),color='Blue')
plot(x,y)
show()

# %% [markdown]
# Now, test-train seperate

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
r.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=r.predict(x_test)

# %%
y_pred
# Out:
# array([ 22656.93537902, 257590.59222631, 324714.49418267, 148514.25154721,
#        127538.03218585, 358276.44516086])

# %%
r.predict([[10]])
# Out:
# array([379252.66452222])

# %%
scatter(x_train,y_train,color='blue')
plot(x,y)
xlabel('Experience ')
ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
r.score(x_test,y_test)
# Out:
# 0.9755026435106734

# %%
r.score(x_train,y_train)
# Out:
# 0.9676008414631219
