# %%
from numpy import *
from matplotlib.pyplot import *
from pandas import *
from seaborn import*
# %matplotlib inline

# %%
df=read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
x = df.iloc[:, 1:2].values
y = df.iloc[:, 2].values

# %%
violinplot(x)
# Out:
# <Axes: >

# %%
violinplot(y,color='violet')
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
r=LinearRegression()
r.fit(x,y)
# Out:
# LinearRegression()

# %%
r.score(x,y)
# Out:
# 0.8551742120609958

# %%
# Step 3 - Visualize Linear Regression Results

scatter(x, y,color = 'red')
plot(x, r.predict(x))
title("Linear Regression")
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %%
pred =r.predict([[74]])

# %%
pred
# Out:
# array([220.34209361])

# %%
from sklearn.preprocessing import PolynomialFeatures
r2=PolynomialFeatures(degree=10)
X2=r2.fit_transform(x)

# %%
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X2, y)
# Out:
# LinearRegression()

# %%
lin_reg_2.score(X2,y)
# Out:
# 0.8588349776397408

# %%
scatter(x, y, color="Black")
plot(x, lin_reg_2.predict(X2))
title("Poly Regression of Degree 10")
# Out:
# Text(0.5, 1.0, 'Poly Regression of Degree 10')

# %%
pred20= lin_reg_2.predict(r2.fit_transform([[80]]))
pred20
# Out:
# array([269.14775335])
